# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#1.导入数据
import pandas as pd
df=pd.read_csv('credit.csv')
df.head()
df.tail()

# %%
#2.可视化查看缺失值
import missingno
missingno.matrix(df)
pd.DataFrame(df.isnull().sum()/shape[0],columns=['missing_rate']).reset_index()
missing.sort_values(by='missing_rate',ascending=False)[:15]

# %%
#3 填写缺失值
missname=[]
for i in df:
  if df[i].isnull().sum() > 0 :
for i in missname:
  df[i]=df[i].fillna(int(df[i].mode()))

# %%
#4 列联表分析
corss_table=pd.crosstab(df.House_State,columns=df.Target,margins=True)
corss_table_rowpct=corss_table.div(corss_table['All'],axis=0)
corss_table_rowpct

# %%
#5 卡方检测
x=df.drop('Target',axis=1)
y=df['Target']
    temp=[]
    for i in df:
        print(i,df[i].value_counts().count())
         if df[i].value_counts().count() < 10 :
                 temp.append(i)

# %%
lianxu=[i for i in df if i not in end]
				lianxu=df[lianxu]
				lianxu=lianxu.drop(['Cust_No','Target'],axis=1)
				lianxu.columns
					显示在df里排除所有在分类里的列
					之后删除Target和Cust_No
				corr=lianxu.corr()
					这里有一个参数method
					默认为pearson 皮尔逊系数
					这里只强调将解一下皮尔逊的原理
					用余弦相似性来进行解释
					还有kendall，spearman
				import matplotlib.pyplot as plt
				plt.figure(figsize=(25,15))
					先设定一个画布大小
				import seaborn as sns
				sns.heatmap(corr,annot=True)
					以热力图的形式画出系数
					annot表示在各个格子里写上数值
				找出所有系数大于0.8的变量
				end = []
				for index_ in corr.index:
				     for col_ in corr.columns:
if corr.loc[index_,col_] >= 0.8 and index_!=col_ and (col_,index_) not in end:
loc相当于一个切片的寻找[]里面分别对应了行和列，就像矩阵一样
之后利用col_,index这样反正判断可以进行一个过滤，防止出现重复的值
				            end.append((index_,col_))
				reg=reg.drop([i[1] for i in end],axis=1).columns

# %%
X = df.drop('Target',axis=1)
			y = df['Target']
			import warnings
			warnings.filterwarnings('ignore')
			from sklearn.feature_selection import RFE
			from sklearn.linear_model import LogisticRegression
x_rfe=RFE(estimator=LogisticRegression(), n_features_to_select=20).fit(X, y)
print(x_rfe.n_features_ ) 
				表示最后要多少个特征
			print(x_rfe.support_ )
				表示用ture和false的形式是否留下 
			print(x_rfe.ranking_ ) 
				用数字来表示，1的表示留下
			print(x_rfe.estimator_ )
				看用的是哪种函数

# %%
保存数据
data.to_csv(“good_feaute.csv”)
